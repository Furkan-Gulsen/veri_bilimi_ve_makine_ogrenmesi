# %% [markdown]
# ## Betimsel İstatistik
# ### Kovaryans
# İki değişken arasındaki ilişkinin değişkenlik ölçüsüdür.
#
# cov( x , y ) = E\[ ( x - E [ x ] ) ] ( y - E [ y ] )

# %% [markdown]
# ---
# ### Korelasyon
# İki değişken arasındaki ilişkiyi, ilişkinin anlamlı olup olmadığını, ilişkinin şiddetini ve yönünü ifade eden istatistiksel bir tekniktir.

# %%
from IPython.display import Image
Image(url="../img/betimsel-istatistik-1.png")
# Out:
# <img src="../img/betimsel-istatistik-1.png"/>

# %% [markdown]
# #### Uygulama

# %%
import seaborn as sns
tips = sns.load_dataset("tips")
df = tips.copy()
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.describe().T
# Out:
#             count       mean       std   min      25%     50%      75%    max
# total_bill  244.0  19.785943  8.902412  3.07  13.3475  17.795  24.1275  50.81
# tip         244.0   2.998279  1.383638  1.00   2.0000   2.900   3.5625  10.00
# size        244.0   2.569672  0.951100  1.00   2.0000   2.000   3.0000   6.00

# %%
# !pip install researchpy
import researchpy as rp
# Out:
# Requirement already satisfied: researchpy in c:\users\mfurk\anaconda3\lib\site-packages (0.1.8)
# Requirement already satisfied: scipy in c:\users\mfurk\anaconda3\lib\site-packages (from researchpy) (1.3.1)
# Requirement already satisfied: numpy in c:\users\mfurk\anaconda3\lib\site-packages (from researchpy) (1.16.5)
# Requirement already satisfied: statsmodels in c:\users\mfurk\anaconda3\lib\site-packages (from researchpy) (0.10.1)
# Requirement already satisfied: pandas in c:\users\mfurk\anaconda3\lib\site-packages (from researchpy) (0.25.1)
# Requirement already satisfied: patsy>=0.4.0 in c:\users\mfurk\anaconda3\lib\site-packages (from statsmodels->researchpy) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\users\mfurk\anaconda3\lib\site-packages (from pandas->researchpy) (2.8.0)
# Requirement already satisfied: pytz>=2017.2 in c:\users\mfurk\anaconda3\lib\site-packages (from pandas->researchpy) (2019.3)
# Requirement already satisfied: six in c:\users\mfurk\anaconda3\lib\site-packages (from patsy>=0.4.0->statsmodels->researchpy) (1.12.0)

# %%
rp.summary_cont(df[["total_bill","tip","size"]])
# Out:
#      Variable      N       Mean        SD        SE  95% Conf.   Interval
# 0  total_bill  244.0  19.785943  8.902412  0.569919  18.663332  20.908554
# 1         tip  244.0   2.998279  1.383638  0.088578   2.823799   3.172758
# 2        size  244.0   2.569672  0.951100  0.060888   2.449737   2.689608

# %%
rp.summary_cat(df[["sex","smoker","day"]])
# Out:
#   Variable Outcome  Count  Percent
# 0      sex    Male    157    64.34
# 1           Female     87    35.66
# 2   smoker      No    151    61.89
# 3              Yes     93    38.11
# 4      day     Sat     87    35.66
# 5              Sun     76    31.15
# 6             Thur     62    25.41
# 7              Fri     19     7.79

# %%
df[["tip","total_bill"]].cov()
# Out:
#                  tip  total_bill
# tip         1.914455    8.323502
# total_bill  8.323502   79.252939

# %%
df[["tip","total_bill"]].corr()
# Out:
#                  tip  total_bill
# tip         1.000000    0.675734
# total_bill  0.675734    1.000000
